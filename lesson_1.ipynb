# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# **Hello everyone and welcome to my first task for unit 2 data science.**

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4]

y = [22,87,0,18]

plt.plot(x, y)
plt.ylabel("Ferrari")
plt.xlabel("Nissan")
plt.title("Cars")
# Out:
# Text(0.5, 1.0, 'Cars')

# %%
import matplotlib.pyplot as plt

# creating the dataset
data = {'ferrari':20, 'nissan':15, 'Lamborghini':30, 
        ' Chevrolet Camaro':35}
courses = list(data.keys())
values = list(data.values())
  #choosing the size of the charts
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot and choosing color
plt.bar(courses, values, color ='Green', 
        width = 0.4)
 
plt.xlabel("Car brands")
plt.ylabel("Number of cars")
plt.title("Cars owned")
plt.show()

# %%
from matplotlib import pyplot as plt
#making my variables 
cars = ['Audi', 'bugatti', 'Ford',
        'Tesla', 'Porsche', 'Toyota']
 
data = [26, 16, 35, 9, 11, 10]
 
# Creating plot 
fig = plt.figure(figsize =(10, 7))
#creating the name for the each pie
plt.pie(data, labels = cars)
 
# show plot
plt.show()
